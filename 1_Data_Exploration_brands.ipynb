# %% [markdown]
# # Importing brands.csv to DataFrame

# %%
import pandas as pd
import numpy as np

# %%
url = "https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=share_link" # brands.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# %% [markdown]
# # Performing basic operations on DataFrame

# %%
brands.head(20)
# Out:
#    short              long
# 0    8MO         8Mobility
# 1    ACM              Acme
# 2    ADN            Adonit
# 3    AII             Aiino
# 4    AKI            Akitio
# 5    ALL         Allocacoc
# 6    AP2             Apple
# 7    APP             Apple
# 8    BAN        Band&Strap
# 9    BEA             Beats
# 10   BEL            Belkin
# 11   BEZ             Be.ez
# 12   BLL        BlueLounge
# 13   BLM  Blue Microphones
# 14   BNQ              BenQ
# 15   BOD        BodyGuardz
# 16   BOO              Booq
# 17   BOS              Bose
# 18   BTC         Boostcase
# 19   CAD              Bose

# %%
brands.tail(20)
# Out:
#     short              long
# 167   TPL           TP-Link
# 168   TRA          Trascend
# 169   TRI             Tribe
# 170   TRK            TrackR
# 171   TRN      Trunk Sleeve
# 172   TUC            Tucano
# 173   TWS      Twelve South
# 174   UAG  Urban Armor Gear
# 175   WAC             Wacom
# 176   WDT   Western Digital
# 177   WHO            Whoosh
# 178   WIK           Wikango
# 179   WIT          Withings
# 180   WOE            Wowewa
# 181   XDO           X-Doria
# 182   XOO            Xoopar
# 183   XRI            X-Rite
# 184   XTO             Xtorm
# 185   ZAG          ZaggKeys
# 186   ZEP              Zepp

# %% [markdown]
# - short – the 3-character code by which the brand can be identified in the first 3 characters of products.sku
# - long – brand name

# %%
brands.columns
# Out:
# Index(['short', 'long'], dtype='object')

# %% [markdown]
# ## Dimensions of DataFrame

# %%
brands.shape
# Out:
# (187, 2)

# %%
brands.size
# Out:
# 374

# %% [markdown]
# ## DataFrame description

# %%
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %%
brands.describe()
# Out:
#        short    long
# count    187     187
# unique   187     181
# top      8MO  Mophie
# freq       1       2

# %%
brands.short.nunique()
# Out:
# 187

# %%
brands.long.nunique()
# Out:
# 181

# %%
brands.long.value_counts().sort_values(ascending = False).head(10)
# Out:
# Mophie        2
# Startech      2
# Jaybird       2
# Apple         2
# Bose          2
# Unknown       2
# Be.ez         1
# BlueLounge    1
# Adonit        1
# Aiino         1
# Name: long, dtype: int64

# %%
# for example apple has two codes
brands.loc[brands.long.isin(['Apple']),:]
# Out:
#   short   long
# 6   AP2  Apple
# 7   APP  Apple

# %% [markdown]
# How is the dataset indexed?

# %%
brands.index
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %% [markdown]
# Are there any duplicates?

# %%
# No
brands.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Are there any missing values?

# %%
# No
print("Missing values distribution: ")
print(brands.isnull().mean())
print("")
# Out:
# Missing values distribution:
# short    0.0
# long     0.0
# dtype: float64

# %%
# Maybe the problem with this DF is in long column. Strings are not formated nicely
